# %% [markdown]
# # IPL Match Winning Prediction

# %% [markdown]
# # About IPL
# The Indian Premier League, or IPL, is a professional Twenty20 cricket league in India.
# The league was founded in 2008 and has since become one of the most popular sporting events in India and around the world.
# The IPL features ten franchise teams representing different cities in India, with players from around the world participating in the league.
# The top four teams advance to the playoffs to determine the IPL champion.
# The league has seen many memorable moments and performances over the years, and is known for its exciting style of cricket, high-scoring matches, and enthusiastic crowds.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matchdf = pd.read_csv('IPL_Matches_2008_2022.csv')
ballbyballdf = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')

# %%
ballbyballdf.shape
# Out:
# (225954, 17)

# %%
print('Number of Rows in Ball By Ball all macthes data is',ballbyballdf.shape[0])
print('Number of Columns in Ball By Ball all macthes data is',ballbyballdf.shape[1])
# Out:
# Number of Rows in Ball By Ball all macthes data is 225954
# Number of Columns in Ball By Ball all macthes data is 17

# %%
ballbyballdf.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
ballbyballdf.isna().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
ballbyballdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
# ...

# %%
ballbyballdf.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# ...

# %%
matchdf.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
matchdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
print('Number of Rows in Macthes data is',matchdf.shape[0])
print('Number of Columns in all Macthes data is',matchdf.shape[1])
# Out:
# Number of Rows in Macthes data is 950
# Number of Columns in all Macthes data is 20

# %%
total_run_inning = ballbyballdf.groupby(['ID','innings']).sum()['total_run'].reset_index()
# Out:
# /tmp/ipykernel_9568/3155198578.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_run_inning = ballbyballdf.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_run_inning.head()
# Out:
#        ID  innings  total_run
# 0  335982        1        222
# 1  335982        2         82
# 2  335983        1        240
# 3  335983        2        207
# 4  335984        1        129

# %%
scores_inning_1 = total_run_inning[total_run_inning['innings']==1]

# %%
scores_inning_1.head()
# Out:
#        ID  innings  total_run
# 0  335982        1        222
# 2  335983        1        240
# 4  335984        1        129
# 6  335985        1        165
# 8  335986        1        110

# %%
scores_inning_1['Target'] = scores_inning_1['total_run'] + 1
# Out:
# /tmp/ipykernel_9568/3707504411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores_inning_1['Target'] = scores_inning_1['total_run'] + 1

# %%
scores_inning_1.head()
# Out:
#        ID  innings  total_run  Target
# 0  335982        1        222     223
# 2  335983        1        240     241
# 4  335984        1        129     130
# 6  335985        1        165     166
# 8  335986        1        110     111

# %%
scores_inning_2 = total_run_inning[total_run_inning['innings']==2]

# %%
scores_inning_2.head()
# Out:
#        ID  innings  total_run
# 1  335982        2         82
# 3  335983        2        207
# 5  335984        2        132
# 7  335985        2        166
# 9  335986        2        112

# %%
# plt.hist(scores_inning_1['total_run'],color='blue')
plt.subplot(1,2,1)
sns.distplot(scores_inning_1['total_run'],color='g')
plt.subplot(1,2,2)
sns.distplot(scores_inning_2['total_run'])
plt.show()
# Out:
# /tmp/ipykernel_9568/2489295722.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(scores_inning_1['total_run'],color='g')
# /tmp/ipykernel_9568/2489295722.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(scores_inning_2['total_run'])

# %% [raw]
# merging the target score data with match dataframe

# %%
matchdf = matchdf.merge(scores_inning_1[['Target','ID']],on='ID')

# %%
matchdf.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
matchdf.shape
# Out:
# (950, 21)

# %%
matchdf.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# Target               0
# dtype: int64

# %% [raw]
# Dropping match rows where their was no result obtained.

# %%
matchdf.dropna(subset=['WinningTeam'],inplace=True)

# %% [raw]
# deleting method column form data as we are only considering full matches where not other menthod applied to obtain result

# %%
matchdf['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
matchdf['method'].value_counts()
# Out:
# D/L    19
# Name: method, dtype: int64

# %%
matchdf.drop(matchdf[matchdf['method'] == 'D/L'].index, inplace=True)

# %%
matchdf.drop('method',axis=1,inplace=True)

# %%
matchdf['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %% [raw]
# #Replacing old Team names with their new names.

# %%
matchdf['Team1'] = matchdf['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matchdf['Team1'] = matchdf['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
matchdf['Team1'] = matchdf['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')


matchdf['Team2'] = matchdf['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matchdf['Team2'] = matchdf['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
matchdf['Team2'] = matchdf['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')


matchdf['WinningTeam'] = matchdf['WinningTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matchdf['WinningTeam'] = matchdf['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')
matchdf['WinningTeam'] = matchdf['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
matchdf['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Rising Pune Supergiants', 'Pune Warriors',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
matchdf['Team2'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals', 'Lucknow Super Giants',
#        'Punjab Kings', 'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Chennai Super Kings', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %%
matchdf['WinningTeam'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Punjab Kings', 'Mumbai Indians',
#        'Lucknow Super Giants', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Chennai Super Kings',
#        'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %% [raw]
# # Dropping the teams which are discontinued from the tournament

# %%
matchdf.drop(matchdf[matchdf['Team1']=='Gujarat Lions'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team1']=='Rising Pune Supergiants'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team1']=='Pune Warriors'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team1']=='Kochi Tuskers Kerala'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team1']=='Rising Pune Supergiant'].index,inplace=True)


matchdf.drop(matchdf[matchdf['Team2']=='Gujarat Lions'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team2']=='Rising Pune Supergiants'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team2']=='Rising Pune Supergiant'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team2']=='Pune Warriors'].index,inplace=True)
matchdf.drop(matchdf[matchdf['Team2']=='Kochi Tuskers Kerala'].index,inplace=True)

# %%
matchdf['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians'], dtype=object)

# %%
matchdf['Team2'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals', 'Lucknow Super Giants',
#        'Punjab Kings', 'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Chennai Super Kings'], dtype=object)

# %%
matchdf['WinningTeam'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Punjab Kings', 'Mumbai Indians',
#        'Lucknow Super Giants', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Chennai Super Kings'], dtype=object)

# %% [raw]
# Check the count of unique teams in Team1, Team2 and Winning Team Column

# %%
cols = ['Team1','Team2','WinningTeam']
for i in cols:
    print(f"Unique Count of Teams in Column {i} is {len(matchdf[i].unique())}")
# Out:
# Unique Count of Teams in Column Team1 is 10
# Unique Count of Teams in Column Team2 is 10
# Unique Count of Teams in Column WinningTeam is 10

# %%
matchdf.isna().sum()
# Out:
# ID                  0
# City               51
# Date                0
# Season              0
# MatchNumber         0
# Team1               0
# Team2               0
# Venue               0
# TossWinner          0
# TossDecision        0
# SuperOver           0
# WinningTeam         0
# WonBy               0
# Margin             13
# Player_of_Match     0
# Team1Players        0
# Team2Players        0
# Umpire1             0
# Umpire2             0
# Target              0
# dtype: int64

# %%
matchdf['Venue'][matchdf['City'].isna()].reset_index()
# Out:
#     index                                Venue
# 0     134  Dubai International Cricket Stadium
# 1     137  Dubai International Cricket Stadium
# 2     138              Sharjah Cricket Stadium
# 3     140  Dubai International Cricket Stadium
# 4     142  Dubai International Cricket Stadium
# 5     143              Sharjah Cricket Stadium
# 6     145  Dubai International Cricket Stadium
# 7     147  Dubai International Cricket Stadium
# 8     148              Sharjah Cricket Stadium
# 9     150  Dubai International Cricket Stadium
# 10    151  Dubai International Cricket Stadium
# 11    153              Sharjah Cricket Stadium
# 12    154  Dubai International Cricket Stadium
# 13    156  Dubai International Cricket Stadium
# 14    159  Dubai International Cricket Stadium
# 15    160  Dubai International Cricket Stadium
# 16    161              Sharjah Cricket Stadium
# 17    163              Sharjah Cricket Stadium
# 18    164  Dubai International Cricket Stadium
# ...

# %% [raw]
# # Replacing The NA values present in CITY with their respective city which we get form Venue Column.

# %%
for i in matchdf[matchdf['City'].isna()]['Venue']:
    if i == "Dubai International Cricket Stadium":
        matchdf['City'].fillna("Dubai",inplace=True)
    else:
        i == "Sharjah Cricket Stadium"
        matchdf['City'].fillna("Sharjah",inplace=True)

# %%
matchdf.isna().sum()
# Out:
# ID                  0
# City                0
# Date                0
# Season              0
# MatchNumber         0
# Team1               0
# Team2               0
# Venue               0
# TossWinner          0
# TossDecision        0
# SuperOver           0
# WinningTeam         0
# WonBy               0
# Margin             13
# Player_of_Match     0
# Team1Players        0
# Team2Players        0
# Umpire1             0
# Umpire2             0
# Target              0
# dtype: int64

# %% [raw]
# # removing the unwanted columns

# %%
matchdf.drop(['Date','Season','MatchNumber','Venue','TossWinner','TossDecision','SuperOver','WonBy','Margin',
              'Player_of_Match','Team1Players','Team2Players','Umpire1','Umpire2'],axis=1,inplace=True)

# %%
matchdf.head()
# Out:
#         ID       City                        Team1                 Team2  \
# 0  1312200  Ahmedabad             Rajasthan Royals        Gujarat Titans
# 1  1312199  Ahmedabad  Royal Challengers Bangalore      Rajasthan Royals
# 2  1312198    Kolkata  Royal Challengers Bangalore  Lucknow Super Giants
# 3  1312197    Kolkata             Rajasthan Royals        Gujarat Titans
# 4  1304116     Mumbai          Sunrisers Hyderabad          Punjab Kings
#
#                    WinningTeam  Target
# 0               Gujarat Titans     131
# 1             Rajasthan Royals     158
# 2  Royal Challengers Bangalore     208
# 3               Gujarat Titans     189
# 4                 Punjab Kings     158

# %%
matchdf['City'].value_counts().plot(kind='bar',color='g')
plt.plot(matchdf['City'].value_counts(),marker='o',color='black')
plt.xlabel('City_Name',color='b')
plt.ylabel('Total_Number_of_Match_Played',color='magenta')
plt.title("City Wise Number of Matches Played")
plt.show()

# %%
sns.countplot(x='WinningTeam',data=matchdf,orient="180")
plt.xticks(rotation=60)
plt.show()

# %%
matchdf.isna().sum()
# Out:
# ID             0
# City           0
# Team1          0
# Team2          0
# WinningTeam    0
# Target         0
# dtype: int64

# %% [raw]
# Merging Matchdf dataset with Ballbyball dataset.

# %%
ballbyballdf.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
ballbyballdf['BattingTeam'].unique()
# Out:
# array(['Rajasthan Royals', 'Gujarat Titans',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Sunrisers Hyderabad', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Rising Pune Supergiants', 'Pune Warriors',
#        'Deccan Chargers', 'Kochi Tuskers Kerala'], dtype=object)

# %% [raw]
# Replacing old Teams name with new team name in ballsbyball dataframe

# %%
ballbyballdf['BattingTeam'] = ballbyballdf['BattingTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
ballbyballdf['BattingTeam'] = ballbyballdf['BattingTeam'].str.replace('Kings XI Punjab','Punjab Kings')
ballbyballdf['BattingTeam'] = ballbyballdf['BattingTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
ballbyballdf['BattingTeam'].unique()
# Out:
# array(['Rajasthan Royals', 'Gujarat Titans',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Sunrisers Hyderabad', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %% [raw]
# Removing the discountinued team from ballbyball dataframe

# %%
ballbyballdf.drop(ballbyballdf[ballbyballdf['BattingTeam']=='Gujarat Lions'].index,inplace=True)
ballbyballdf.drop(ballbyballdf[ballbyballdf['BattingTeam']=='Rising Pune Supergiants'].index,inplace=True)
ballbyballdf.drop(ballbyballdf[ballbyballdf['BattingTeam']=='Pune Warriors'].index,inplace=True)
ballbyballdf.drop(ballbyballdf[ballbyballdf['BattingTeam']=='Kochi Tuskers Kerala'].index,inplace=True)
ballbyballdf.drop(ballbyballdf[ballbyballdf['BattingTeam']=='Rising Pune Supergiant'].index,inplace=True)

# %%
print(f"Unique Count of Teams in Column Batting Team is {len(ballbyballdf['BattingTeam'].unique())}")
# Out:
# Unique Count of Teams in Column Batting Team is 10

# %%
ballbyballdf = matchdf.merge(ballbyballdf,on='ID')

# %%
ballbyballdf.head()
# Out:
#         ID       City             Team1           Team2     WinningTeam  \
# 0  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 1  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 2  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 3  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 4  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#    Target  innings  overs  ballnumber       batter  ... extra_type  \
# 0     131        1      0           1  YBK Jaiswal  ...        NaN
# 1     131        1      0           2  YBK Jaiswal  ...    legbyes
# 2     131        1      0           3   JC Buttler  ...        NaN
# 3     131        1      0           4  YBK Jaiswal  ...        NaN
# 4     131        1      0           5  YBK Jaiswal  ...        NaN
#
#   batsman_run extras_run  total_run  non_boundary  isWicketDelivery  \
# ...

# %%
ballbyballdf['BattingTeam'].value_counts()
# Out:
# Mumbai Indians                 25727
# Sunrisers Hyderabad            25003
# Royal Challengers Bangalore    24213
# Delhi Capitals                 24015
# Kolkata Knight Riders          23926
# Chennai Super Kings            23885
# Punjab Kings                   23775
# Rajasthan Royals               21790
# Gujarat Titans                  1971
# Lucknow Super Giants            1840
# Name: BattingTeam, dtype: int64

# %%
ballbyballdf['BattingTeam'].value_counts().plot(kind='bar',color='y')
plt.legend()
plt.show()

# %% [raw]
# Select the rows where we are in 2nd innings

# %%
ballbyballdf = ballbyballdf[ballbyballdf['innings']==2]

# %%
ballbyballdf.shape
# Out:
# (95056, 22)

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... extra_type  \
# 120     131        2      0           1       WP Saha  ...        NaN
# 121     131        2      0           2       WP Saha  ...        NaN
# 122     131        2      0           3       WP Saha  ...        NaN
# 123     131        2      0           4  Shubman Gill  ...        NaN
# 124     131        2      0           5  Shubman Gill  ...        NaN
#
#     batsman_run extras_run  total_run  non_boundary  isWicketDelivery  \
# ...

# %%
ballbyballdf.columns
# Out:
# Index(['ID', 'City', 'Team1', 'Team2', 'WinningTeam', 'Target', 'innings',
#        'overs', 'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam'],
#       dtype='object')

# %% [raw]
# Inserting a new row current_score after each ball

# %%
ballbyballdf['Current_score'] = ballbyballdf.groupby('ID')['total_run'].cumsum()

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... batsman_run  \
# 120     131        2      0           1       WP Saha  ...           0
# 121     131        2      0           2       WP Saha  ...           0
# 122     131        2      0           3       WP Saha  ...           1
# 123     131        2      0           4  Shubman Gill  ...           0
# 124     131        2      0           5  Shubman Gill  ...           0
#
#     extras_run total_run  non_boundary  isWicketDelivery  player_out  kind  \
# ...

# %% [raw]
# creating a new column required run by subtracting current score from target

# %%
ballbyballdf['Runs_required'] = np.where((ballbyballdf['Target']-ballbyballdf['Current_score'])>=0,ballbyballdf['Target']-ballbyballdf['Current_score'],0)

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... extras_run  \
# 120     131        2      0           1       WP Saha  ...          0
# 121     131        2      0           2       WP Saha  ...          0
# 122     131        2      0           3       WP Saha  ...          0
# 123     131        2      0           4  Shubman Gill  ...          0
# 124     131        2      0           5  Shubman Gill  ...          0
#
#     total_run non_boundary  isWicketDelivery  player_out  kind  \
# ...

# %% [raw]
# creating a new column balls left in inning by subtracting overs and ballnumber from total balls in inning(120)

# %%
ballbyballdf['Balls_left'] = np.where((120-ballbyballdf['overs']*6-ballbyballdf['ballnumber'])>=0,(120-ballbyballdf['overs']*6-ballbyballdf['ballnumber']),0)

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... total_run  \
# 120     131        2      0           1       WP Saha  ...         0
# 121     131        2      0           2       WP Saha  ...         0
# 122     131        2      0           3       WP Saha  ...         1
# 123     131        2      0           4  Shubman Gill  ...         0
# 124     131        2      0           5  Shubman Gill  ...         0
#
#     non_boundary isWicketDelivery  player_out  kind  fielders_involved  \
# ...

# %% [raw]
# adding columns current run rate and required run rate

# %%
ballbyballdf['Current_runrate'] = ballbyballdf['Current_score'] / (ballbyballdf['overs'] +( ballbyballdf['ballnumber']/6))

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... non_boundary  \
# 120     131        2      0           1       WP Saha  ...            0
# 121     131        2      0           2       WP Saha  ...            0
# 122     131        2      0           3       WP Saha  ...            0
# 123     131        2      0           4  Shubman Gill  ...            0
# 124     131        2      0           5  Shubman Gill  ...            0
#
#     isWicketDelivery player_out  kind  fielders_involved     BattingTeam  \
# ...

# %%
ballbyballdf['Required_runrate'] = np.where(ballbyballdf['Balls_left']>0,(ballbyballdf['Runs_required']*6)/ballbyballdf['Balls_left'],0)

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... isWicketDelivery  \
# 120     131        2      0           1       WP Saha  ...                0
# 121     131        2      0           2       WP Saha  ...                0
# 122     131        2      0           3       WP Saha  ...                0
# 123     131        2      0           4  Shubman Gill  ...                0
# 124     131        2      0           5  Shubman Gill  ...                0
#
# ...

# %%
ballbyballdf.isna().sum()
# Out:
# ID                       0
# City                     0
# Team1                    0
# Team2                    0
# WinningTeam              0
# Target                   0
# innings                  0
# overs                    0
# ballnumber               0
# batter                   0
# bowler                   0
# non-striker              0
# extra_type           90017
# batsman_run              0
# extras_run               0
# total_run                0
# non_boundary             0
# isWicketDelivery         0
# player_out           90379
# kind                 90379
# fielders_involved    91744
# BattingTeam              0
# Current_score            0
# Runs_required            0
# Balls_left               0
# Current_runrate          0
# Required_runrate         0
# dtype: int64

# %% [raw]
# created wicket left column

# %%
ballbyballdf['Wicket_left'] = 10-ballbyballdf.groupby('ID')['isWicketDelivery'].cumsum()

# %% [raw]
# Created the Result Column which is also our target varibale by putting 1 if team batting 1st won the match and putted 0 if team batted 2nd won the match.

# %%
ballbyballdf['Result'] = np.where(ballbyballdf['WinningTeam']==ballbyballdf['BattingTeam'],1,0)

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... kind  \
# 120     131        2      0           1       WP Saha  ...  NaN
# 121     131        2      0           2       WP Saha  ...  NaN
# 122     131        2      0           3       WP Saha  ...  NaN
# 123     131        2      0           4  Shubman Gill  ...  NaN
# 124     131        2      0           5  Shubman Gill  ...  NaN
#
#     fielders_involved     BattingTeam  Current_score  Runs_required  \
# ...

# %% [raw]
# Created a bowling team column

# %%
ballbyballdf['BowlingTeam'] = np.where(ballbyballdf['Team1']==ballbyballdf['BattingTeam'],ballbyballdf['Team2'],ballbyballdf['Team1'])

# %%
ballbyballdf.head()
# Out:
#           ID       City             Team1           Team2     WinningTeam  \
# 120  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 121  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 122  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 123  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
# 124  1312200  Ahmedabad  Rajasthan Royals  Gujarat Titans  Gujarat Titans
#
#      Target  innings  overs  ballnumber        batter  ... fielders_involved  \
# 120     131        2      0           1       WP Saha  ...               NaN
# 121     131        2      0           2       WP Saha  ...               NaN
# 122     131        2      0           3       WP Saha  ...               NaN
# 123     131        2      0           4  Shubman Gill  ...               NaN
# 124     131        2      0           5  Shubman Gill  ...               NaN
#
# ...

# %%
ballbyballdf.corr()
# Out:
# /tmp/ipykernel_9568/2444205750.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ballbyballdf.corr()
#                         ID    Target  innings     overs  ballnumber  \
# ID                1.000000  0.144211      NaN  0.010674   -0.000145
# Target            0.144211  1.000000      NaN  0.071237    0.007498
# innings                NaN       NaN      NaN       NaN         NaN
# overs             0.010674  0.071237      NaN  1.000000   -0.011348
# ballnumber       -0.000145  0.007498      NaN -0.011348    1.000000
# batsman_run       0.024840  0.057622      NaN  0.066741    0.000665
# extras_run       -0.014187  0.000529      NaN -0.001094   -0.000723
# total_run         0.021964  0.058141      NaN  0.066976    0.000514
# non_boundary      0.000383 -0.004888      NaN -0.001726   -0.004258
# ...

# %%
ballbyballdf.columns
# Out:
# Index(['ID', 'City', 'Team1', 'Team2', 'WinningTeam', 'Target', 'innings',
#        'overs', 'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam', 'Current_score', 'Runs_required', 'Balls_left',
#        'Current_runrate', 'Required_runrate', 'Wicket_left', 'Result',
#        'BowlingTeam'],
#       dtype='object')

# %% [raw]
# Droping the non-corelated and columns from which we have derived showing higher co-relation than existing 1.

# %%
ballbyballdf.drop(['ID','Team1', 'Team2', 'WinningTeam','innings',
       'overs', 'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
       'batsman_run', 'extras_run', 'total_run', 'non_boundary',
       'isWicketDelivery', 'player_out', 'kind', 'fielders_involved','Current_score'],axis=1,inplace=True)

# %%
ballbyballdf.head()
# Out:
#           City  Target     BattingTeam  Runs_required  Balls_left  \
# 120  Ahmedabad     131  Gujarat Titans            131         119
# 121  Ahmedabad     131  Gujarat Titans            131         118
# 122  Ahmedabad     131  Gujarat Titans            130         117
# 123  Ahmedabad     131  Gujarat Titans            130         116
# 124  Ahmedabad     131  Gujarat Titans            130         115
#
#      Current_runrate  Required_runrate  Wicket_left  Result       BowlingTeam
# 120              0.0          6.605042           10       1  Rajasthan Royals
# 121              0.0          6.661017           10       1  Rajasthan Royals
# 122              2.0          6.666667           10       1  Rajasthan Royals
# 123              1.5          6.724138           10       1  Rajasthan Royals
# 124              1.2          6.782609           10       1  Rajasthan Royals

# %%
ballbyballdf.columns
# Out:
# Index(['City', 'Target', 'BattingTeam', 'Runs_required', 'Balls_left',
#        'Current_runrate', 'Required_runrate', 'Wicket_left', 'Result',
#        'BowlingTeam'],
#       dtype='object')

# %%
ballbyballdf.shape
# Out:
# (95056, 10)

# %%
ballbyballdf.isna().sum()
# Out:
# City                0
# Target              0
# BattingTeam         0
# Runs_required       0
# Balls_left          0
# Current_runrate     0
# Required_runrate    0
# Wicket_left         0
# Result              0
# BowlingTeam         0
# dtype: int64

# %%
ballbyballdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95056 entries, 120 to 196144
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              95056 non-null  object
#  1   Target            95056 non-null  int64
#  2   BattingTeam       95056 non-null  object
#  3   Runs_required     95056 non-null  int64
#  4   Balls_left        95056 non-null  int64
#  5   Current_runrate   95056 non-null  float64
#  6   Required_runrate  95056 non-null  float64
#  7   Wicket_left       95056 non-null  int64
#  8   Result            95056 non-null  int64
#  9   BowlingTeam       95056 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 8.0+ MB

# %%
ballbyballdf.describe()
# Out:
#              Target  Runs_required    Balls_left  Current_runrate  \
# count  95056.000000   95056.000000  95056.000000     95056.000000
# mean     166.372086      93.099762     62.528068         7.407374
# std       28.745818      49.871646     33.429515         2.227865
# min       68.000000       0.000000      0.000000         0.000000
# 25%      148.000000      54.000000     34.000000         6.272727
# 50%      166.000000      92.000000     63.000000         7.469988
# 75%      186.000000     131.000000     91.000000         8.636364
# max      247.000000     247.000000    119.000000        36.000000
#
#        Required_runrate   Wicket_left        Result
# count      95056.000000  95056.000000  95056.000000
# mean          10.666263      7.532907      0.523060
# std           13.174401      2.155106      0.499471
# min            0.000000      0.000000      0.000000
# 25%            7.212605      6.000000      0.000000
# 50%            8.941176      8.000000      1.000000
# ...

# %%
ballbyballdf.corr()
# Out:
# /tmp/ipykernel_9568/2444205750.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ballbyballdf.corr()
#                     Target  Runs_required  Balls_left  Current_runrate  \
# Target            1.000000       0.394294   -0.071571         0.252934
# Runs_required     0.394294       1.000000    0.841108        -0.230187
# Balls_left       -0.071571       0.841108    1.000000        -0.187278
# Current_runrate   0.252934      -0.230187   -0.187278         1.000000
# Required_runrate  0.264228      -0.035318   -0.247253        -0.020459
# Wicket_left      -0.169595       0.492834    0.753318         0.031660
# Result           -0.433696      -0.257257    0.054434         0.129521
#
#                   Required_runrate  Wicket_left    Result
# Target                    0.264228    -0.169595 -0.433696
# ...

# %% [raw]
# preprocessing the data for City, Winning Team and Losing team using label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ballbyballdf['City'] = le.fit_transform(ballbyballdf['City'])
ballbyballdf['BattingTeam'] = le.fit_transform(ballbyballdf['BattingTeam'])
ballbyballdf['BowlingTeam'] = le.fit_transform(ballbyballdf['BowlingTeam'])

# %%
print(ballbyballdf['City'].unique())
print(ballbyballdf['BattingTeam'].unique())
print(ballbyballdf['BowlingTeam'].unique())
# Out:
# [ 1 20 21 23 25 12 28  0 10  8 15 29  7  3 17 16  2 26 27  9 11 22 18  6
#  13  4 24 19 14  5]
# [2 7 4 6 5 8 3 9 1 0]
# [7 8 9 1 0 2 4 3 6 5]

# %%
ballbyballdf.loc[120:240]
# Out:
#      City  Target  BattingTeam  Runs_required  Balls_left  Current_runrate  \
# 120     1     131            2            131         119         0.000000
# 121     1     131            2            131         118         0.000000
# 122     1     131            2            130         117         2.000000
# 123     1     131            2            130         116         1.500000
# 124     1     131            2            130         115         1.200000
# ..    ...     ...          ...            ...         ...              ...
# 228     1     131            2              7          15         7.085714
# 229     1     131            2              7          14         7.018868
# 230     1     131            2              6          13         7.009346
# 231     1     131            2              4          12         7.055556
# 232     1     131            2              0          11         7.321101
#
#      Required_runrate  Wicket_left  Result  BowlingTeam
# ...

# %%
ballbyballdf.corr()
# Out:
#                       City    Target  BattingTeam  Runs_required  Balls_left  \
# City              1.000000 -0.012964    -0.046920      -0.000163   -0.001585
# Target           -0.012964  1.000000     0.034962       0.394294   -0.071571
# BattingTeam      -0.046920  0.034962     1.000000       0.026755    0.000113
# Runs_required    -0.000163  0.394294     0.026755       1.000000    0.841108
# Balls_left       -0.001585 -0.071571     0.000113       0.841108    1.000000
# Current_runrate  -0.030700  0.252934    -0.013565      -0.230187   -0.187278
# Required_runrate -0.011111  0.264228     0.034110      -0.035318   -0.247253
# Wicket_left      -0.029487 -0.169595    -0.012150       0.492834    0.753318
# Result            0.021553 -0.433696    -0.084835      -0.257257    0.054434
# BowlingTeam      -0.044893 -0.024081    -0.150343      -0.008311   -0.004014
#
#                   Current_runrate  Required_runrate  Wicket_left    Result  \
# ...

# %%
x=ballbyballdf.drop('Result',axis=1)
y=ballbyballdf['Result']

# %%
col_names = x.columns
col_names
# Out:
# Index(['City', 'Target', 'BattingTeam', 'Runs_required', 'Balls_left',
#        'Current_runrate', 'Required_runrate', 'Wicket_left', 'BowlingTeam'],
#       dtype='object')

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# x = scaler.fit_transform(x)
# x = pd.DataFrame(x,columns=col_names)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25)

# %%
from  sklearn.linear_model import LogisticRegression
model_lg = LogisticRegression()
model_lg.fit(x_train,y_train)
y_pred = model_lg.predict(x_test)
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy Score : ",accuracy)
f1_Score = f1_score(y_test,y_pred)
print("f1 Score : ",f1_Score)
Roc_Aucscore = roc_auc_score(y_test,y_pred)
print("Roc_Auc_Score : ",Roc_Aucscore)
# Out:
# Accuracy Score :  0.7750799528698872
# f1 Score :  0.7901864573110894
# Roc_Auc_Score :  0.7734066645401861
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from  sklearn.tree import DecisionTreeClassifier
model_dt = DecisionTreeClassifier(max_depth=15)
model_dt.fit(x_train,y_train)
y_pred = model_dt.predict(x_test)
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy Score : ",accuracy)
f1_Score = f1_score(y_test,y_pred)
print("f1 Score : ",f1_Score)
Roc_Aucscore = roc_auc_score(y_test,y_pred)
print("Roc_Auc_Score : ",Roc_Aucscore)
# Out:
# Accuracy Score :  0.9653677832014812
# f1 Score :  0.9669623860944965
# Roc_Auc_Score :  0.9652888105998697

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
from  sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(max_depth=15)
model_rf.fit(x_train,y_train)
y_pred = model_rf.predict(x_test)
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy Score : ",accuracy)
f1_Score = f1_score(y_test,y_pred)
print("f1 Score : ",f1_Score)
Roc_Aucscore = roc_auc_score(y_test,y_pred)
print("Roc_Auc_Score : ",Roc_Aucscore)
# Out:
# Accuracy Score :  0.9917943107221007
# f1 Score :  0.9921671018276763
# Roc_Auc_Score :  0.9918097554115637

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
from  xgboost import XGBClassifier
model_xgb = XGBClassifier()
model_xgb.fit(x_train,y_train)
y_pred = model_xgb.predict(x_test)
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy Score : ",accuracy)
f1_Score = f1_score(y_test,y_pred)
print("f1 Score : ",f1_Score)
Roc_Aucscore = roc_auc_score(y_test,y_pred)
print("Roc_Auc_Score : ",Roc_Aucscore)
# Out:
# Accuracy Score :  0.9977276552768894
# f1 Score :  0.9978327179322524
# Roc_Auc_Score :  0.9977141895325808

# %%
# model_xgb.predict([[6,170,5,9,54,8.09,9,8,6]])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
from  sklearn.svm import SVC
model_svm = SVC()
model_svm.fit(x_train,y_train)
y_pred = model_svm.predict(x_test)
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy Score : ",accuracy)
f1_Score = f1_score(y_test,y_pred)
print("f1 Score : ",f1_Score)
Roc_Aucscore = roc_auc_score(y_test,y_pred)
print("Roc_Auc_Score : ",Roc_Aucscore)
# Out:
# Accuracy Score :  0.7766790102676318
# f1 Score :  0.7921676130800861
# Roc_Auc_Score :  0.7748872067881988

# %%
import pickle
with open('svm.pkl','wb') as file1:
    pickle.dump(model_svm,file1)
    file1.close()
    
with open('dt.pkl','wb') as file2:
    pickle.dump(model_dt,file2)
    file2.close()

with open('rf.pkl','wb') as file3:
    pickle.dump(model_rf,file3)
    file3.close()

with open('lg.pkl','wb') as file4:
    pickle.dump(model_lg,file4)
    file4.close()
    
with open('xgb.pkl','wb') as file5:
    pickle.dump(model_xgb,file5)
    file5.close()

# %%
# result 1 if batting team wins
# result 0 if bowling team wins
